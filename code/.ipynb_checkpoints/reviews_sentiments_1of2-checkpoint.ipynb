# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 3: NLP & APIs

# %% [markdown]
# ---
# # Part 1
#
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# Singapore's climate do not vary much from month to month, and there are no distinct wet or dry seasons.<sup>[1](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation)</sup> However, a higher rainfall occurs during the two monsoon seasons from November to January and June to September.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# As such, we want to <font color = 'green'>**predict future dengue cases using the weather data in Singapore**</font> so appropriate measures can be put in place to minimise the number of dengue cases.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# ### Data Sources
#
# * [Singapore's Monthly Weather Data – singstat.gov.sg](https://tablebuilder.singstat.gov.sg/table/TS/M890081)
# * [Singapore's Weekly Infectious Diseases – data.gov.sg](https://data.gov.sg/dataset/weekly-infectious-disease-bulletin-cases)

# %% [markdown]
# ---
# # Part 2
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Importing all libraries used: 

import requests
import pandas as pd 
import pandas as pd       
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import re

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ###
#
# ####

# %%
# Using API to retrieve app reviews of Assassins Creed IV: Black Flag. ID of game is 242050
ass_creed_res = requests.get(url='https://store.steampowered.com/appreviews/242050?json=1').json()

# %%
# Identifying the keys of the dictionary. 
ass_creed_res.keys()
# Out:
# dict_keys(['success', 'query_summary', 'reviews', 'cursor'])

# %%
# Accessing Query Summary: Note that the current reviews are only the first 20.
ass_creed_res['query_summary']
# Out:
# {'num_reviews': 20,
#  'review_score': 8,
#  'review_score_desc': 'Very Positive',
#  'total_positive': 19322,
#  'total_negative': 2734,
#  'total_reviews': 22056}

# %% [markdown]
# Total reviews for the game on steam was 22,056. This should be the total amount we will be able to work with the classify our data

# %%
# Cursor will be needed to access then next 20 reviews.
ass_creed_res['cursor']
# Out:
# 'AoIIPxCyEH66sZwE'

# %%
# Trying to access the next 20 reviews.
requests.get(url='https://store.steampowered.com/appreviews/242050?json=1&cursor=AoIIPxCyEH66sZwE').json()
# Out:
# {'success': 1,
#  'query_summary': {'num_reviews': 20},
#  'reviews': [{'recommendationid': '141428546',
#    'author': {'steamid': '76561198827542571',
#     'num_games_owned': 0,
#     'num_reviews': 3,
#     'playtime_forever': 2248,
#     'playtime_last_two_weeks': 0,
#     'playtime_at_review': 30,
#     'last_played': 1689279738},
#    'language': 'english',
#    'review': 'The game starts in windowed mode, it is impossible to switch to full screen mode.',
#    'timestamp_created': 1688627521,
#    'timestamp_updated': 1688627521,
#    'voted_up': False,
#    'votes_up': 8,
#    'votes_funny': 0,
#    'weighted_vote_score': '0.564755380153656006',
#    'comment_count': 0,
#    'steam_purchase': True,
#    'received_for_free': False,
#    'written_during_early_access': False,
#    'hidden_in_steam_china': True,
#    'steam_china_location': ''},
#   {'recommendationid': '141598517',
#    'author': {'steamid': '76561198298204417',
#     'num_games_owned': 156,
# ...

# %% [markdown]
# Now to try and automate this process in a function

# %%
# Defining a function to automate this process

def get_reviews(appid, params={'json':1}):
    url = 'https://store.steampowered.com/appreviews/'
    response = requests.get(url=url+appid, params=params)
    return response.json()

def get_n_reviews(appid, n=100):
    reviews = []
    cursor = '*'
    params = {
            'json' : 1,
            'filter' : 'all',
            'language' : 'english',
            'day_range' : 9223372036854775807,
            'review_type' : 'all',
            'purchase_type' : 'all'
            }

    while n > 0:
        params['cursor'] = cursor.encode()
        params['num_per_page'] = min(100, n)
        n -= 100

        response = get_reviews(appid, params)
        cursor = response['cursor']
        reviews += response['reviews']

        if len(response['reviews']) < 100: break

    return reviews

# %%
# Converting results of all reviews into a dataframe
reviews = pd.DataFrame(get_n_reviews('242050', n =22056))

# %%
reviews.head()
# Out:
#   recommendationid                                             author  \
# 0         85460916  {'steamid': '76561198156016347', 'num_games_ow...
# 1         76223418  {'steamid': '76561198149047566', 'num_games_ow...
# 2         69682784  {'steamid': '76561197990642312', 'num_games_ow...
# 3         88206852  {'steamid': '76561198982554607', 'num_games_ow...
# 4         71445029  {'steamid': '76561198849119685', 'num_games_ow...
#
#   language                                             review  \
# 0  english           The only game where i avoid fast travel.
# 1  english  This is the Best Assassins Creed game and Prob...
# 2  english  Best game ever, iv'e been playing from day one...
# 3  english                            Shanties Before Panties
# 4  english  Best part of the game are the sea shanties. Lo...
#
#    timestamp_created  timestamp_updated  voted_up  votes_up  votes_funny  \
# 0         1611779242         1611779242      True      3657          179
# ...

# %%
# Turning Author into a dictionary
auth_dict = dict(enumerate(reviews['author'], 1))

auth_dict
# Out:
# {1: {'steamid': '76561198156016347',
#   'num_games_owned': 267,
#   'num_reviews': 21,
#   'playtime_forever': 2856,
#   'playtime_last_two_weeks': 0,
#   'playtime_at_review': 2856,
#   'last_played': 1518982944},
#  2: {'steamid': '76561198149047566',
#   'num_games_owned': 0,
#   'num_reviews': 52,
#   'playtime_forever': 1838,
#   'playtime_last_two_weeks': 0,
#   'playtime_at_review': 1838,
#   'last_played': 1593601946},
#  3: {'steamid': '76561197990642312',
#   'num_games_owned': 0,
#   'num_reviews': 2,
#   'playtime_forever': 116875,
#   'playtime_last_two_weeks': 89,
#   'playtime_at_review': 90196,
#   'last_played': 1690346522},
#  4: {'steamid': '76561198982554607',
#   'num_games_owned': 77,
#   'num_reviews': 4,
#   'playtime_forever': 4719,
#   'playtime_last_two_weeks': 0,
#   'playtime_at_review': 4036,
#   'last_played': 1617472093},
#  5: {'steamid': '76561198849119685',
#   'num_games_owned': 0,
#   'num_reviews': 10,
#   'playtime_forever': 1592,
# ...

# %%
#Turning author dictionary into a dataframe
author = pd.DataFrame.from_dict(auth_dict, orient = 'index').reset_index(drop=True)
author.head()
# Out:
#              steamid  num_games_owned  num_reviews  playtime_forever  \
# 0  76561198156016347              267           21              2856
# 1  76561198149047566                0           52              1838
# 2  76561197990642312                0            2            116875
# 3  76561198982554607               77            4              4719
# 4  76561198849119685                0           10              1592
#
#    playtime_last_two_weeks  playtime_at_review  last_played
# 0                        0              2856.0   1518982944
# 1                        0              1838.0   1593601946
# 2                       89             90196.0   1690346522
# 3                        0              4036.0   1617472093
# 4                        0              1177.0   1644543449

# %%
reviews = author.join(reviews)
reviews.head()
# Out:
#              steamid  num_games_owned  num_reviews  playtime_forever  \
# 0  76561198156016347              267           21              2856
# 1  76561198149047566                0           52              1838
# 2  76561197990642312                0            2            116875
# 3  76561198982554607               77            4              4719
# 4  76561198849119685                0           10              1592
#
#    playtime_last_two_weeks  playtime_at_review  last_played recommendationid  \
# 0                        0              2856.0   1518982944         85460916
# 1                        0              1838.0   1593601946         76223418
# 2                       89             90196.0   1690346522         69682784
# 3                        0              4036.0   1617472093         88206852
# 4                        0              1177.0   1644543449         71445029
#
#                                               author language  ...  \
# ...

# %%
reviews.drop(columns = ['author', 'timestamp_dev_responded', 'developer_response', 'steam_china_location'], inplace = True)
reviews.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 reviews.drop(columns = ['author', 'timestamp_dev_responded', 'developer_response', 'steam_china_location'], inplace = True)
#       2 reviews.head()
#
# File ~/Desktop/DATA_JOURNEY/Mambaforge/envs/dsi-sg/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
reviews.duplicated().sum()
# Out:
# 0

# %%
reviews_only = reviews[['review', 'weighted_vote_score']]
reviews_only.head()
# Out:
#                                               review   weighted_vote_score
# 0           The only game where i avoid fast travel.  0.986497402191162109
# 1  This is the Best Assassins Creed game and Prob...  0.978906214237213135
# 2  Best game ever, iv'e been playing from day one...  0.978628873825073242
# 3                            Shanties Before Panties  0.974160850048065186
# 4  Best part of the game are the sea shanties. Lo...  0.958124220371246338

# %%
reviews_only.tail()
# Out:
#                                                   review weighted_vote_score
# 22051  you cant spell assasin without the "ASS" *wink...                   0
# 22052  Good content, demotivating game-play (linear, ...                   0
# 22053  Likes:\nBeautiful Game\nShip Battles\n\nDislik...                   0
# 22054  Awesome game! No problems with bad perfomance,...                   0
# 22055  proper return to form for the series.\nI'd ven...                   0

# %%
reviews_only['weighted_vote_score'] = reviews_only['weighted_vote_score'].astype(float)
# Out:
# /var/folders/_s/4bjxzfvd5jj9yc3x2ssfcc0h0000gn/T/ipykernel_64387/3215306547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_only['weighted_vote_score'] = reviews_only['weighted_vote_score'].astype(float)

# %%
reviews_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22056 entries, 0 to 22055
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   review               22056 non-null  object
#  1   weighted_vote_score  22056 non-null  float64
#  2   positive             22056 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 517.1+ KB

# %%
for i in range(reviews_only.shape[0]):
    if reviews_only.loc[i, 'weighted_vote_score'] >= 0.5:
        reviews_only.loc[i, 'positive'] = True
    elif reviews_only.loc[i, 'weighted_vote_score'] < 0.5:
        reviews_only.loc[i, 'positive'] = False

reviews_only.head()
# Out:
#                                               review  weighted_vote_score  \
# 0           The only game where i avoid fast travel.             0.986497
# 1  This is the Best Assassins Creed game and Prob...             0.978906
# 2  Best game ever, iv'e been playing from day one...             0.978629
# 3                            Shanties Before Panties             0.974161
# 4  Best part of the game are the sea shanties. Lo...             0.958124
#
#   positive
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %%
reviews_only['positive']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 22051    False
# 22052    False
# 22053    False
# 22054    False
# 22055    False
# Name: positive, Length: 22056, dtype: object

# %%
X = reviews_only.drop('positive', axis = 1)
y = reviews_only['positive']

# %%
tokenizer = RegexpTokenizer('\w+|\$[\d\.]+|\S+')

# %%
for i in range(reviews_only.shape[0]):
    reviews_only.loc[i, 'review_split'] = tokenizer.tokenize(reviews_only.loc[i, 'review'].lower())
# Out:
# /var/folders/_s/4bjxzfvd5jj9yc3x2ssfcc0h0000gn/T/ipykernel_64387/3067109290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_only.loc[i, 'review_split'] = tokenizer.tokenize(reviews_only.loc[i, 'review'].lower())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 2
#       1 for i in range(reviews_only.shape[0]):
# ----> 2     reviews_only.loc[i, 'review_split'] = tokenizer.tokenize(reviews_only.loc[i, 'review'].lower())
#
# File ~/Desktop/DATA_JOURNEY/Mambaforge/envs/dsi-sg/lib/python3.8/site-packages/pandas/core/indexing.py:818, in _LocationIndexer.__setitem__(self, key, value)
# ...

# %%
cvec = CountVectorizer()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/DATA_JOURNEY/Mambaforge/envs/dsi-sg/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/Desktop/DATA_JOURNEY/Mambaforge/envs/dsi-sg/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Desktop/DATA_JOURNEY/Mambaforge/envs/dsi-sg/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tokened'
#
# ...

# %% [markdown]
# ---
#
# # Data Dictionary
#
# ----
#
# *weather_disease_monthly_data.csv*
#
# |Feature|Type|Datasource|Description|
# |---|---|---|---|
# |dengue_fever_cases|integer|weekly-infectious-disease-bulletin-cases|Number of recorded cases of Dengue Fever in an epidemiological week|
# |dhf_cases|integer|weekly-infectious-disease-bulletin-cases|Number of recorded cases of Dengue Haemorrhagic Fever in an epidemiological week|
# |daily_max_temp|float|monthly_nea_singstat_rain_humidity|The monthly and annual mean daily minimum temperature recorded at the Changi Climate Station|
# |daily_min_temp|float|monthly_nea_singstat_rain_humidity|The monthly and annual mean daily maximum temperature recorded at the Changi Climate Station|
# |extreme_max_temp|float|monthly_nea_singstat_rain_humidity|The monthly extreme maximum air temperature recorded at the Changi Climate Station|
# |extreme_min_temp|float|monthly_nea_singstat_rain_humidity|The absolute extreme minimum air temperature recorded at the Changi Climate Station|
# |total_rainfall|float|monthly_nea_singstat_rain_humidity|The total monthly rainfall recorded at the Changi Climate Station|
# |total_highest_daily_rainfall|float|monthly_nea_singstat_rain_humidity|The highest daily total rainfall for the month recorded at the Changi Climate Station|
# |no_of_rainy_days|float|monthly_nea_singstat_rain_humidity|The number of rain days* in a month recorded at the Changi Climate Station|
# |sunshine_daily_mean|float|monthly_nea_singstat_rain_humidity|The monthly mean sunshine hours in a day recorded at the Changi Climate Station|
# |min_relative_humidity|float|monthly_nea_singstat_rain_humidity|The absolute extreme minimum relative humidity for the month recorded at the Changi Climate Station|
# |mean_daily_humidity|float|monthly_nea_singstat_rain_humidity|The monthly mean relative humidity recorded at the Changi Climate Station|
# |monthly_mean_temp|float|monthly_nea_singstat_rain_humidity|The monthly mean air temperature recorded at the Changi Climate Station|
#
# *\* day with rainfall amount of 0.2mm or more*

# %% [markdown]
# ---
# # Exploratory Data Analysis
#
# ---

# %% [markdown]
# ### Summary Statistics

# %%
print(weather_disease.shape)
print(weather_disease.info())

weather_disease.describe()

# There are no null values
# Out:
# (132, 14)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132 entries, 0 to 131
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date                          132 non-null    datetime64[ns]
#  1   dengue_fever_cases            132 non-null    int64
#  2   dhf_cases                     132 non-null    int64
#  3   daily_max_temp                132 non-null    float64
#  4   daily_min_temp                132 non-null    float64
#  5   extreme_max_temp              132 non-null    float64
#  6   extreme_min_temp              132 non-null    float64
#  7   total_rainfall                132 non-null    float64
#  8   total_highest_daily_rainfall  132 non-null    float64
#  9   no_of_rainy_days              132 non-null    float64
#  10  sunshine_daily_mean           132 non-null    float64
#  11  min_relative_humidity         132 non-null    float64
# ...

# %% [markdown]
# No null values were found in any columns.
#
# Based on min/max and std of each column, we can see there is a huge range for the dengue_fever_cases, and there may be extreme outliers that reside in both dengue_fever_cases as well as total_rainfall.

# %%
# Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.

weather_disease_sd = {key: std_dev(values) for key, values in weather_disease.iloc[:,1:].to_dict(orient='list').items()}
weather_disease_sd
# Out:
# {'dengue_fever_cases': 240.519864292874,
#  'dhf_cases': 1.3739027880748862,
#  'daily_max_temp': 4.973900781778541,
#  'daily_min_temp': 3.8041390694399047,
#  'extreme_max_temp': 5.332503954997605,
#  'extreme_min_temp': 3.3374145731944793,
#  'total_rainfall': 30.685505393303973,
#  'total_highest_daily_rainfall': 7.342053717961361,
#  'no_of_rainy_days': 1.9338032662675635,
#  'sunshine_daily_mean': 1.1965245802221414,
#  'min_relative_humidity': 7.971196879181564,
#  'mean_daily_humidity': 14.129254984314498,
#  'monthly_mean_temp': 4.285402630346851}

# %% [markdown]
# ## Finding additional trends in the initial analysis

# %%
# Which month(s) have the highest total rainfall in each year from 2012 to 2022?
for year in np.arange(2012,2023) :
    yearly_max = weather_disease[(weather_disease['date'].dt.year == year)]['total_rainfall'].max()
    yearly_date = weather_disease[(weather_disease['date'].dt.year == year) & (weather_disease['total_rainfall'] == yearly_max)]['date']
    print(f"Highest total rainfall in {year} was {yearly_max} on the months of {yearly_date.dt.month_name().values}")
# Out:
# Highest total rainfall in 2012 was 363.4 on the months of ['December']
# Highest total rainfall in 2013 was 395.2 on the months of ['February']
# Highest total rainfall in 2014 was 250.8 on the months of ['November']
# Highest total rainfall in 2015 was 302.0 on the months of ['December']
# Highest total rainfall in 2016 was 292.6 on the months of ['December']
# Highest total rainfall in 2017 was 371.2 on the months of ['December']
# Highest total rainfall in 2018 was 287.0 on the months of ['January']
# Highest total rainfall in 2019 was 421.5 on the months of ['December']
# Highest total rainfall in 2020 was 255.6 on the months of ['May']
# Highest total rainfall in 2021 was 692.8 on the months of ['January']
# Highest total rainfall in 2022 was 313.8 on the months of ['November']

# %%
# Which month(s) have the highest dengue cases in each year from 2012 to 2022?

for year in np.arange(2012,2023) :
    yearly_max = weather_disease[(weather_disease['date'].dt.year == year)]['dengue_fever_cases'].max()
    yearly_date = weather_disease[(weather_disease['date'].dt.year == year) & (weather_disease['dengue_fever_cases'] == yearly_max)]['date']
    print(f"Highest number of dengue cases in {year} was {yearly_max} on the months of {yearly_date.dt.month_name().values}")
# Out:
# Highest number of dengue cases in 2012 was 599 on the months of ['July']
# Highest number of dengue cases in 2013 was 4000 on the months of ['June']
# Highest number of dengue cases in 2014 was 3083 on the months of ['July']
# Highest number of dengue cases in 2015 was 1519 on the months of ['December']
# Highest number of dengue cases in 2016 was 2969 on the months of ['January']
# Highest number of dengue cases in 2017 was 362 on the months of ['January']
# Highest number of dengue cases in 2018 was 617 on the months of ['December']
# Highest number of dengue cases in 2019 was 2497 on the months of ['July']
# Highest number of dengue cases in 2020 was 6817 on the months of ['August']
# Highest number of dengue cases in 2021 was 979 on the months of ['January']
# Highest number of dengue cases in 2022 was 6443 on the months of ['May']

# %%
# Which month(s) have the lowest total rainfall in each year from 2012 to 2022?

for year in np.arange(2012,2023) :
    yearly_min = weather_disease[(weather_disease['date'].dt.year == year)]['total_rainfall'].min()
    yearly_date = weather_disease[(weather_disease['date'].dt.year == year) & (weather_disease['total_rainfall'] == yearly_min)]['date']
    print(f"Lowest total rainfall in {year} was {yearly_min} on the months of {yearly_date.dt.month_name().values}")
# Out:
# Lowest total rainfall in 2012 was 53.0 on the months of ['June']
# Lowest total rainfall in 2013 was 85.8 on the months of ['March']
# Lowest total rainfall in 2014 was 0.2 on the months of ['February']
# Lowest total rainfall in 2015 was 18.8 on the months of ['February']
# Lowest total rainfall in 2016 was 6.2 on the months of ['March']
# Lowest total rainfall in 2017 was 79.6 on the months of ['July']
# Lowest total rainfall in 2018 was 14.8 on the months of ['February']
# Lowest total rainfall in 2019 was 11.8 on the months of ['August']
# Lowest total rainfall in 2020 was 65.0 on the months of ['February']
# Lowest total rainfall in 2021 was 1.0 on the months of ['February']
# Lowest total rainfall in 2022 was 99.8 on the months of ['January']

# %%
# Which month(s) have the lowest dengue cases in each year from 2012 to 2022?

for year in np.arange(2012,2023) :
    yearly_min = weather_disease[(weather_disease['date'].dt.year == year)]['dengue_fever_cases'].min()
    yearly_date = weather_disease[(weather_disease['date'].dt.year == year) & (weather_disease['dengue_fever_cases'] == yearly_min)]['date']
    print(f"Lowest number of dengue cases in {year} was {yearly_min} on the months of {yearly_date.dt.month_name().values}")
# Out:
# Lowest number of dengue cases in 2012 was 229 on the months of ['March']
# Lowest number of dengue cases in 2013 was 819 on the months of ['January']
# Lowest number of dengue cases in 2014 was 775 on the months of ['December']
# Lowest number of dengue cases in 2015 was 477 on the months of ['April']
# Lowest number of dengue cases in 2016 was 276 on the months of ['December']
# Lowest number of dengue cases in 2017 was 147 on the months of ['March']
# Lowest number of dengue cases in 2018 was 161 on the months of ['March']
# Lowest number of dengue cases in 2019 was 523 on the months of ['April']
# Lowest number of dengue cases in 2020 was 887 on the months of ['December']
# Lowest number of dengue cases in 2021 was 209 on the months of ['November']
# Lowest number of dengue cases in 2022 was 752 on the months of ['January']

# %%
# Which years have the highest and lowest total rainfall in the date range of analysis?

high_rain_y = weather_disease[weather_disease['total_rainfall']==weather_disease['total_rainfall'].max()]

low_rain_y = weather_disease[weather_disease['total_rainfall']==weather_disease['total_rainfall'].min()]

print(f"The highest total rainfall was {high_rain_y['total_rainfall'].values} in the year {high_rain_y['date'].dt.year.values}")

print(f"The lowest total rainfall was {low_rain_y['total_rainfall'].values} in the year {low_rain_y['date'].dt.year.values}")
# Out:
# The highest total rainfall was [692.8] in the year [2021]
# The lowest total rainfall was [0.2] in the year [2014]

# %% [markdown]
# Note: syntax filtering used so as to be able to reference the year in print f-string

# %%
# Which years have the highest and lowest dengue cases in the date range of analysis?

high_cases_y = weather_disease[weather_disease['dengue_fever_cases']==weather_disease['dengue_fever_cases'].max()]

low_cases_y = weather_disease[weather_disease['dengue_fever_cases']==weather_disease['dengue_fever_cases'].min()]

print(f"The highest number of cases was {high_cases_y['dengue_fever_cases'].values} in the year {high_cases_y['date'].dt.year.values}")

print(f"The lowest number of cases was {low_cases_y['dengue_fever_cases'].values} in the year {low_cases_y['date'].dt.year.values}")
# Out:
# The highest number of cases was [6817] in the year [2020]
# The lowest number of cases was [147] in the year [2017]

# %% [markdown]
# Note: syntax filtering used so as to be able to reference the year in print f-string

# %%
# Which months have the highest and lowest number of rainy days?

for year in np.arange(2012,2023) :
    rain_max_m = weather_disease[(weather_disease['date'].dt.year == year)]['no_of_rainy_days'].max()
    rain_max_m_day = weather_disease[(weather_disease['date'].dt.year == year) & (weather_disease['no_of_rainy_days'] == rain_max_m)]['date']
    
    print(f"Highest number of rainy days in {year} was {rain_max_m} days on the months of {rain_max_m_day.dt.month_name().values}")
# Out:
# Highest number of rainy days in 2012 was 22.0 days on the months of ['November' 'December']
# Highest number of rainy days in 2013 was 22.0 days on the months of ['February' 'November']
# Highest number of rainy days in 2014 was 23.0 days on the months of ['November']
# Highest number of rainy days in 2015 was 19.0 days on the months of ['December']
# Highest number of rainy days in 2016 was 23.0 days on the months of ['December']
# Highest number of rainy days in 2017 was 24.0 days on the months of ['November']
# Highest number of rainy days in 2018 was 27.0 days on the months of ['November']
# Highest number of rainy days in 2019 was 16.0 days on the months of ['June']
# Highest number of rainy days in 2020 was 22.0 days on the months of ['July']
# Highest number of rainy days in 2021 was 24.0 days on the months of ['August']
# Highest number of rainy days in 2022 was 27.0 days on the months of ['October']

# %%
for year in np.arange(2012,2023) :
    rain_min_m = weather_disease[(weather_disease['date'].dt.year == year)]['no_of_rainy_days'].min()
    rain_min_m_day = weather_disease[(weather_disease['date'].dt.year == year) & (weather_disease['no_of_rainy_days'] == rain_min_m)]['date']

    print(f"Lowest number of rainy days in {year} was {rain_min_m} days on the months of {rain_min_m_day.dt.month_name().values}")
# Out:
# Lowest number of rainy days in 2012 was 8.0 days on the months of ['June']
# Lowest number of rainy days in 2013 was 10.0 days on the months of ['March']
# Lowest number of rainy days in 2014 was 1.0 days on the months of ['February']
# Lowest number of rainy days in 2015 was 5.0 days on the months of ['March']
# Lowest number of rainy days in 2016 was 6.0 days on the months of ['March']
# Lowest number of rainy days in 2017 was 9.0 days on the months of ['July']
# Lowest number of rainy days in 2018 was 5.0 days on the months of ['February']
# Lowest number of rainy days in 2019 was 4.0 days on the months of ['September']
# Lowest number of rainy days in 2020 was 6.0 days on the months of ['January']
# Lowest number of rainy days in 2021 was 2.0 days on the months of ['February']
# Lowest number of rainy days in 2022 was 9.0 days on the months of ['January']

# %%
# Are there any outliers months in the dataset?

weather_disease.describe()
# Out:
#        dengue_fever_cases   dhf_cases  daily_max_temp  daily_min_temp  \
# count          132.000000  132.000000      132.000000      132.000000
# mean          1242.598485    3.212121       31.622727       25.376515
# std           1288.361145    3.574785        0.801867        0.683375
# min            147.000000    0.000000       29.100000       23.800000
# 25%            357.000000    1.000000       31.100000       24.800000
# 50%            884.000000    2.000000       31.600000       25.350000
# 75%           1619.750000    4.000000       32.100000       25.900000
# max           6817.000000   19.000000       33.500000       27.100000
#
#        extreme_max_temp  extreme_min_temp  total_rainfall  \
# count        132.000000        132.000000      132.000000
# mean          33.515909         22.834091      164.347727
# std            0.772606          0.806636      101.176542
# min           31.600000         20.900000        0.200000
# ...

# %% [markdown]
# From the above data, we can see there is a trend for the most number of rain days to fall between the period of October and December, within which, the highest amount of rainfall falls between November and December.
#
# The lowest rainfall to fall in the months of February, March, and June.
#
# The dengue cases tend to spike between June and August, and drop between November and December.

# %% [markdown]
# ---
# # Visualising the Data
#
# ----

# %% [markdown]
# ### Heatmap Correlation
#
# Working with our data, we want to visualise the correlation of each column and if there is a correlation there so as to know which factors we need to explore deeper.
#
# This can be best done with a heatmap to give a good overview of the data we are working with.

# %%
plt.figure(figsize = (50,10))

corr = weather_disease.corr(numeric_only=True)

corr_mask = np.zeros_like(corr)
corr_mask[np.triu_indices_from(corr_mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = corr_mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5, cmap= 'coolwarm')

# %% [markdown]
# The main relationships we are looking at are between dengue and the rest of the weather data.
#
# From here, we can see that there is not a huge correlation between both DF and DHF cases, and the rest of the weather data.
#
# Though, notably, we can take note of the monthly mean temperature, as well as daily minimum temperature, which comparitively have a slightly higher correlation to DF and DHF compared to the rest of the data.
#
# ## Histograms & Outliers
#
# Next, we want to look at the histograms of some of the important factors.

# %%
plt.figure(figsize = (16,15))

dengue_hist = plt.subplot(3, 3, 1)
dengue_hist.set_title('Histogram of Dengue Fever Cases')
dengue_hist.hist(weather_disease['dengue_fever_cases']);

dhf_hist = plt.subplot(3, 3, 2)
dhf_hist.set_title('Histogram of DHF Cases')
dhf_hist.hist(weather_disease['dhf_cases']);

max_temp_hist = plt.subplot(3, 3, 3)
max_temp_hist.set_title('Histogram of Max Temperature')
max_temp_hist.hist(weather_disease['daily_max_temp']);

xtreme_max_temp = plt.subplot(3, 3, 4)
xtreme_max_temp.set_title('Histogram of Extreme Max Temperature')
xtreme_max_temp.hist(weather_disease['extreme_max_temp']); 

daily_mean_temp = plt.subplot(3, 3, 5)
daily_mean_temp.set_title('Histogram of Monthly Mean Temperature')
daily_mean_temp.hist(weather_disease['monthly_mean_temp']); 

total_rainfall_hist = plt.subplot(3, 3, 6)
total_rainfall_hist.set_title('Histogram of Total Rainfall')
total_rainfall_hist.hist(weather_disease['total_rainfall']); 

raind_days_hist = plt.subplot(3, 3, 7)
raind_days_hist.set_title('Histogram of Days of Rain')
raind_days_hist.hist(weather_disease['no_of_rainy_days']); 

sunshine_hist = plt.subplot(3, 3, 8)
sunshine_hist.set_title('Histogram of Sunshine Days')
sunshine_hist.hist(weather_disease['sunshine_daily_mean']); 

humidity_hist = plt.subplot(3, 3, 9)
humidity_hist.set_title('Histogram of Mean Humidity')
humidity_hist.hist(weather_disease['mean_daily_humidity']);

# %% [markdown]
# From the histograms above, we can see that most of them follow a normal distribution.
#
# However, the outstanding histograms are the number of DF and DHC cases.
#
# We can see that there is a small amount of cases in the extremeities in both. These few values are our outliers in the dengue cases. However, it is important for us to keep this in as there may be many factors contributing to this.
#
# ## Comparing Trends
#
# Next, we want to compare our dengue data to our weather data to see what trends we can find.
#
# ### Temperature x Dengue
#
# Breaking this down, we will first look at **temperature** and its relationship with dengue.

# %%
def two_scales_temp(ax1, data2, y_label):
    ax2 = ax1.twinx()
    ax1.plot(weather_disease['date'], weather_disease['dengue_fever_cases'], color='darkblue', alpha=0.9)
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Dengue Numbers', color = 'darkblue')
    ax2.plot(weather_disease['date'], data2, color='orange', alpha =0.6)
    ax2.set_ylabel(y_label, color = 'orange')
    ax1.set_title(f'Comparing Dengue numbers to {data2.name}')
    return ax1, ax2

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))
ax1, ax1a = two_scales_temp(ax1, weather_disease['monthly_mean_temp'], ('Temperature ('+chr(176)+'C)'))
ax2, ax2a = two_scales_temp(ax2, weather_disease['daily_max_temp'], ('Temperature ('+chr(176)+'C)'))

plt.tight_layout()

fig, (ax3, ax4) = plt.subplots(1,2, figsize=(12,5))
ax3, ax3a = two_scales_temp(ax3, weather_disease['extreme_max_temp'], ('Temperature ('+chr(176)+'C)'))
ax4, ax4a = two_scales_temp(ax4, weather_disease['extreme_min_temp'], ('Temperature ('+chr(176)+'C)'))

plt.tight_layout()

# %% [markdown]
# From these, we can see some peaks in the temperature data that corresponds to the peaks in the dengue numbers.
#
# Notably, monthly mean temperature, as well as extreme minimum tempurature.
#
# Although not all the peaks corrospond with each other, these could be due to multiple reasons, such as heavy measures being put in place by the government to try and mitigate the situation.<sup>[3](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3373041/)</sup>
#
# Interestingly enough, the peaks for the trends seem to have a small gap in time between them. This could be due to the delay in the time it takes for the Aedes aegypti to breed, get infected, and transmit the disease. This delay seems to be a bit more consistent with the extreme minimum temperature.
#
#
# ### Rainfall x Dengue
#
# Now, let's look at rainfall, and how it trends compared against dengue.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))
ax1, ax1a = two_scales_temp(ax1, weather_disease['total_rainfall'], 'Rainfall (mm)')
ax2, ax2a = two_scales_temp(ax2, weather_disease['no_of_rainy_days'], 'Rainfall (mm)')

plt.tight_layout()

# %% [markdown]
# From the above graphs, there does not seem to be a very clear trend of rainfall against dengue.
#
# We cannot conclude anything from these graphs above. In the later section, we will try plotting different graphs to see if any other conclusions can be drawn from them.
#
# ### Humidity x Dengue
#
# The last factor left in our weather data is the humidity. Plotting this against the dengue trends, let us see what we can find.

# %%
jfig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))
ax1, ax1a = two_scales_temp(ax1, weather_disease['mean_daily_humidity'], 'Humidity (%)')
ax2, ax2a = two_scales_temp(ax2, weather_disease['min_relative_humidity'], 'Humidity (%)')

plt.tight_layout()

# %% [markdown]
# Similarly to our previous findings with rainfall, there is no clear relationship in the trends between humidity and dengue. We will need to plot more graphs for further analysis befor coming to any conclusions.

# %% [markdown]
# ## Scatter Graphs
#
# We need to compare the data using different types of graph before being able to come to a final conclusion.
#
# Taking our findings from the previous section, we want to further explore the relationship of the stronger correlations, as well as the weaker correlations. As such, we compared the data between dengue and its relationship to monthly mean temperature, extreme minimum temperature, total rainfall, and mean daily humidity.

# %%
# Let's also see some of these on a scatter graph

fig, axs = plt.subplots(2,2, figsize = (16,16))
axs[0][0].scatter(weather_disease['dengue_fever_cases'], weather_disease['monthly_mean_temp']);
axs[0][0].set_title("Dengue Cases versus monthly Mean Temp") ;
axs[0][0].set_xlabel("Dengue Cases");
axs[0][0].set_ylabel(f"Temperature ({chr(176)}C)");

axs[0][1].scatter(weather_disease['dengue_fever_cases'], weather_disease['extreme_min_temp']);
axs[0][1].set_title("Dengue Cases versus Extreme Min Temp");
axs[0][1].set_xlabel("Dengue Cases");
axs[0][1].set_ylabel(f"Temperature ({chr(176)}C)");

axs[1][0].scatter(weather_disease['dengue_fever_cases'], weather_disease['total_rainfall']);
axs[1][0].set_title("Dengue Cases versus Total Rainfall");
axs[1][0].set_xlabel("Dengue Cases");
axs[1][0].set_ylabel("Rainfall (mm)");

axs[1][1].scatter(weather_disease['dengue_fever_cases'], weather_disease['mean_daily_humidity']);
axs[1][1].set_title("Dengue Cases versus Mean Humidity");
axs[1][1].set_xlabel("Dengue Cases");
axs[1][1].set_ylabel("Humidity (%)");

# %%
weather_disease[weather_disease['total_rainfall']==weather_disease['total_rainfall'].max()]
# Out:
#           date  dengue_fever_cases  dhf_cases  daily_max_temp  daily_min_temp  \
# 108 2021-01-31                 979          3            29.1            23.8
#
#      extreme_max_temp  extreme_min_temp  total_rainfall  \
# 108              31.6              21.7           692.8
#
#      total_highest_daily_rainfall  no_of_rainy_days  sunshine_daily_mean  \
# 108                         210.6              17.0                  4.2
#
#      min_relative_humidity  mean_daily_humidity  monthly_mean_temp
# 108                   55.0                 82.6               26.0

# %%
weather_disease[weather_disease['total_rainfall']>400]
# Out:
#           date  dengue_fever_cases  dhf_cases  daily_max_temp  daily_min_temp  \
# 95  2019-12-31                1348          1            30.1            24.6
# 108 2021-01-31                 979          3            29.1            23.8
#
#      extreme_max_temp  extreme_min_temp  total_rainfall  \
# 95               32.3              22.7           421.5
# 108              31.6              21.7           692.8
#
#      total_highest_daily_rainfall  no_of_rainy_days  sunshine_daily_mean  \
# 95                           74.2              14.0                  4.8
# 108                         210.6              17.0                  4.2
#
#      min_relative_humidity  mean_daily_humidity  monthly_mean_temp
# 95                    47.0                 83.9               26.7
# 108                   55.0                 82.6               26.0

# %% [markdown]
# ### Temperature x Dengue
#
# From the scatter graph with temperatures, we can see the cluster leaning towards the left side of the graph. Concentrating on the mean temperature, we can see a few outliers on the top right quadrant of the graph as well. This graph tells us that there are definitely a consistent amount of dengue cases in Singapore, but even more so with temperatures above 27.5&deg;C
#
# Upon further research, this is because Aedes aegypti's optimum breeding temperatures are between 28°C - 30°C <sup>[7](https://www.sciencedirect.com/science/article/pii/S0048969721001832#:~:text=Studies%20have%20shown%20that%20an,et%20al.%2C%202009) [3](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3373041/)</sup> hence, we see higher number of cases above this range. A similar trend can be seen on the graph with extreme minimum temperatures.
#
# ### Rainfall x Dengue
#
# The graph comparing rainfall to dengue cases show a slight downward trend. However, it is also very clustered towards the bottom left. It can be seen that beyond a certain level of rainfall (421.5mm), there were no cases of DF. There is 1 outlier in the top right graph, where there was a huge amount of rainfall, but also a decent number of DF cases. From the data, we can see that this was in the start of 2021. This could be due to a number of factors, including work from home situations rising, as well as a new serotype of DF occuring.<sup>[8](https://www.straitstimes.com/singapore/health/singapore-records-19-dengue-deaths-in-2022-nearly-four-times-2021-s-toll)</sup>
#
# ### Humidity x Dengue
#
# As for the humidity, the trend of the scatter graph seems to follow quite closely to the temperature graphs. We can conclude that humidity is directly affected by temperature, which results in the similar results in trends.

# %% [markdown]
# ### DHF Comparisons
#
# Our earlier graphs were related to the DF cases. But what about the DHF cases? As DHF is more severe, perhaps we should analyse these data seprately from DF.
#
# #### Temperature
#
# We will plot the temperature graphs in relation to DHF.

# %%
fig, axs = plt.subplots(2,2, figsize = (16,16))
axs[0][0].scatter(weather_disease['dhf_cases'], weather_disease['monthly_mean_temp']);
axs[0][0].set_title("DHF versus Daily Mean Temp");
axs[0][0].set_xlabel("DHF Cases");
axs[0][0].set_ylabel(f"Temperature ({chr(176)}C)");

axs[0][1].scatter(weather_disease['dhf_cases'], weather_disease['extreme_min_temp']);
axs[0][1].set_title("DHF versus Extreme Min Temp");
axs[0][1].set_xlabel("DHF Cases");
axs[0][1].set_ylabel(f"Temperature ({chr(176)}C)");

axs[1][0].scatter(weather_disease['dhf_cases'], weather_disease['daily_max_temp']);
axs[1][0].set_title("DHF versus Daily Max Temp");
axs[1][0].set_xlabel("DHF Cases");
axs[1][0].set_ylabel(f"Temperature ({chr(176)}C)");

axs[1][1].scatter(weather_disease['dhf_cases'], weather_disease['extreme_max_temp']);
axs[1][1].set_title("DHF versus Extreme Max Temp");
axs[1][1].set_xlabel("DHF Cases");
axs[1][1].set_ylabel(f"Temperature ({chr(176)}C)");

# %% [markdown]
# The graphs on the DHF against temperature show much stronger positive correlations between the two factors, with the exception of extreme minimum temperature.
#
# We can also see the same trend as DF, where after a ceratin temperature, there are more high case numbers of DHF. The value here is 27.5&deg;C as well.
#
# We could conclude from the above graphs that temperature does indeed have a positive correlation to the number of DHF cases, especially if temperature rises above 27.5&deg;C.
#
# #### Sunshine, Rainfall, and Humidity
#
# Lastly, let us look into the correlation of dengue on sunshine, rainfall, and humidity.

# %%
fig, axs = plt.subplots(2,2, figsize = (16,16))
axs[0][0].scatter(weather_disease['dhf_cases'], weather_disease['sunshine_daily_mean']); #sunshine
axs[0][0].set_title("DHF versus Sunshine") ;
axs[0][0].set_xlabel("DHF Cases");
axs[0][0].set_ylabel("Days");

axs[0][1].scatter(weather_disease['dhf_cases'], weather_disease['total_rainfall']); #rainfal
axs[0][1].set_title("DHF versus Total Rainfall");
axs[0][1].set_xlabel("DHF Cases");
axs[0][1].set_ylabel("Rainfall (mm)");

axs[1][0].scatter(weather_disease['dhf_cases'], weather_disease['no_of_rainy_days']); #rainday
axs[1][0].set_title("DHF versus No. of Rain Days");
axs[1][0].set_xlabel("DHF Cases");
axs[1][0].set_ylabel("Days");

axs[1][1].scatter(weather_disease['dhf_cases'], weather_disease['mean_daily_humidity']); #humidity
axs[1][1].set_title("DHF versus Humidity");
axs[1][1].set_xlabel("DHF Cases");
axs[1][1].set_ylabel("Humidity (%)");

# %% [markdown]
# We can see that the correlation in DHF data has a slightly clearer trend. This could be due to there being fewer DHF cases, as they are more severe cases of DF.
#
# We can see that the trends are very similar to what we found in the same graphs of DF. Similar from before, we see that after a certain threshold, 421.5mm, the number of cases are almost none, with a similar outlier from before also from the same period which could be due to the previously mentioned work from home rates, as well as new dengue serotypes.
#
# Similarly, as humidity and sunshine days are directly correlated to total rainfall, we can see that they also show a correlation between the two.
#
# We can conclude that higher rainfalls above the approximate 450mm threshold lead to much fewer dengue cases.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# As we explored the trends of dengue and weather in Singapore, we can see that the 2 main weather that could affect dengue trends is temperature, and rainfall.
#
# The main trend being as temperature rises higher than 27.5&deg;C, more spikes in both DF and DHF cases can be seen. On the inverse, when total rainfall falls above 450mm, it leads to much fewer DF and DHF cases.
#
# Based on my exploration on whether we are able to predict future dengue cases using the weather data in Singapore, we can say that there is a small relationship between the temperature and rainfall, and its effects on the number of dengue cases.
#
# However, as we have seen throughout this exploration, the relationship is not extremely strong. More research shows many other factors affecting the number of DF and DHF cases, including changes in serotype as well as the COVID-19 pandemic, and the preventive measures put in place by the government. Therefore it cannot be completely predicted only using weather data in Singapore
